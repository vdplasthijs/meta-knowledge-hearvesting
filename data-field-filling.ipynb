# %%
from cheatsheet import CHEATSHEETS
from prompt import PROMPTS
from grobidmonkey import reader
from webutils import readWebContent, downloadAndParseXML

monkeyReader = reader.MonkeyReader('monkey') # or 'lxml' or 'x2d'

# Get the web content
url = "https://datahuiswadden.openearth.nl/geonetwork/srv/api/records/TF1TbsTxTqykP5rv6MXJEg"
soup = readWebContent(url)
if soup is None:
    raise ValueError("Failed to retrieve web content")

# Extract text from the webpage - adjust the selector based on the webpage structure
# This is a basic example - you might need to modify based on the specific webpage
text = soup.get_text(separator='\n', strip=True)

text_xml, _ = downloadAndParseXML("https://datahuiswadden.openearth.nl/geonetwork/srv/api/records/A0h06_NlSEuNlium5OO3FA/formatters/xml")
text += "\n" + text_xml

# %%
from openai import OpenAI
from dotenv import load_dotenv
from utils import (
    logger,
    clean_str,
    compute_mdhash_id,
    decode_tokens_by_tiktoken,
    encode_string_by_tiktoken,
    is_float_regex,
    normalize_extracted_info,
    pack_user_ass_to_openai_messages,
    split_string_by_multi_markers,
    use_llm_func_with_cache,
)
from collections import defaultdict

import tiktoken
import re
import os

llm_model = "gpt-4"
load_dotenv()

def chunk_text(text: str, max_tokens: int = 6000) -> list[str]:
    """Split text into chunks that fit within token limit"""
    encoder = tiktoken.encoding_for_model(llm_model)
    tokens = encoder.encode(text)
    chunks = []
    
    current_chunk = []
    current_length = 0
    
    for token in tokens:
        if current_length + 1 > max_tokens:
            # Convert chunk back to text
            chunk_text = encoder.decode(current_chunk)
            chunks.append(chunk_text)
            current_chunk = []
            current_length = 0
        
        current_chunk.append(token)
        current_length += 1
    
    if current_chunk:
        chunks.append(encoder.decode(current_chunk))
    
    return chunks

def extract_entities(text: str, entity_types: list[str], special_interest: str = "") -> dict:
    # Split text into chunks
    chunks = chunk_text(text, max_tokens=4000)  # Leave room for completion
    
    all_nodes = defaultdict(list)
    all_edges = defaultdict(list)
    
    client = OpenAI(
        api_key=os.getenv("OPENAI_API_KEY")
    )

    nightly_entities_prompt = CHEATSHEETS["nightly_entity_template"].format(
        tuple_delimiter=PROMPTS["DEFAULT_TUPLE_DELIMITER"],
        record_delimiter=PROMPTS["DEFAULT_RECORD_DELIMITER"],
    )
    
    # Process each chunk
    for chunk in chunks:
        formatted_prompt = {
            "language": "English",
            "tuple_delimiter": PROMPTS["DEFAULT_TUPLE_DELIMITER"],
            "record_delimiter": PROMPTS["DEFAULT_RECORD_DELIMITER"],
            "completion_delimiter": PROMPTS["DEFAULT_COMPLETION_DELIMITER"],
            "entity_types": entity_types,
            "special_interest": special_interest,
            "nightly_entities": nightly_entities_prompt,
            "input_text": chunk
        }
        
        response = client.chat.completions.create(
            model=llm_model,
            messages=[
                {
                    "role": "system",
                    "content": "You are an AI trained to extract entities(meta data fields) and relationships from text."
                },
                {
                    "role": "user",
                    "content": _format_prompt(formatted_prompt)
                }
            ],
            temperature=0.0,
            max_tokens=2000
        )

        print("----------------\nresponse.choices[0].message.content:\n", response.choices[0].message.content)
        
        # Process the chunk results
        nodes, edges = _process_extraction_result(
            response.choices[0].message.content,
            chunk_key=compute_mdhash_id(chunk),
            file_path="unknown_source"
        )
        
        # Merge results
        for key, value in nodes.items():
            all_nodes[key].extend(value)
        for key, value in edges.items():
            all_edges[key].extend(value)
    
    return all_nodes, all_edges
    

def _format_prompt(params: dict) -> str:
    # Format the prompt template with the provided parameters
    prompt_template = CHEATSHEETS["fill_nightly"]
    return prompt_template.format(**params)

def _handle_single_entity_extraction(
    record_attributes: list[str],
    chunk_key: str,
    file_path: str = "unknown_source",
):
    if len(record_attributes) < 4 or record_attributes[0] != '"entity"':
        return None

    # Clean and validate entity name
    entity_name = clean_str(record_attributes[1]).strip('"')
    if not entity_name.strip():
        logger.warning(
            f"Entity extraction error: empty entity name in: {record_attributes}"
        )
        return None

    # Normalize entity name
    entity_name = normalize_extracted_info(entity_name, is_entity=True)

    # Clean and validate entity type
    entity_type = clean_str(record_attributes[2]).strip('"')
    if not entity_type.strip() or entity_type.startswith('("'):
        logger.warning(
            f"Entity extraction error: invalid entity type in: {record_attributes}"
        )
        return None

    # Clean and validate description
    entity_description = clean_str(record_attributes[3])
    entity_description = normalize_extracted_info(entity_description)

    if not entity_description.strip():
        logger.warning(
            f"Entity extraction error: empty description for entity '{entity_name}' of type '{entity_type}'"
        )
        return None

    return dict(
        entity_name=entity_name,
        entity_type=entity_type,
        description=entity_description,
        source_id=chunk_key,
        file_path=file_path,
    )


def _handle_single_relationship_extraction(
    record_attributes: list[str],
    chunk_key: str,
    file_path: str = "unknown_source",
):
    if len(record_attributes) < 5 or record_attributes[0] != '"relationship"':
        return None
    # add this record as edge
    source = clean_str(record_attributes[1])
    target = clean_str(record_attributes[2])

    # Normalize source and target entity names
    source = normalize_extracted_info(source, is_entity=True)
    target = normalize_extracted_info(target, is_entity=True)

    edge_description = clean_str(record_attributes[3])
    edge_description = normalize_extracted_info(edge_description)

    edge_keywords = clean_str(record_attributes[4]).strip('"').strip("'")
    edge_source_id = chunk_key
    weight = (
        float(record_attributes[-1].strip('"').strip("'"))
        if is_float_regex(record_attributes[-1])
        else 1.0
    )
    return dict(
        src_id=source,
        tgt_id=target,
        weight=weight,
        description=edge_description,
        keywords=edge_keywords,
        source_id=edge_source_id,
        file_path=file_path,
    )

def _process_extraction_result(
        result: str, chunk_key: str, file_path: str = "unknown_source"
    ):
        """Process a single extraction result (either initial or gleaning)
        Args:
            result (str): The extraction result to process
            chunk_key (str): The chunk key for source tracking
            file_path (str): The file path for citation
        Returns:
            tuple: (nodes_dict, edges_dict) containing the extracted entities and relationships
        """
        context_base = dict(
            tuple_delimiter=PROMPTS["DEFAULT_TUPLE_DELIMITER"],
            record_delimiter=PROMPTS["DEFAULT_RECORD_DELIMITER"],
            completion_delimiter=PROMPTS["DEFAULT_COMPLETION_DELIMITER"],
        )
        maybe_nodes = defaultdict(list)
        maybe_edges = defaultdict(list)

        records = split_string_by_multi_markers(
            result,
            [context_base["record_delimiter"], context_base["completion_delimiter"], "\n"],
        )

        print(f"Extracted records: {records}\n")

        for record in records:
            print(f"Processing record: {record}")
            # Add parentheses if they don't exist
            if not record.startswith('('):
                record = f'({record})'
            if not record.endswith(')'):
                record = f'{record})'
            record = re.search(r"\((.*)\)", record)
            if record is None:
                print(
                    f"Record extraction error: invalid record format in: {record}"
                )
                continue
            record = record.group(1)
            record_attributes = split_string_by_multi_markers(
                record, [context_base["tuple_delimiter"]]
            )

            if_entities = _handle_single_entity_extraction(
                record_attributes, chunk_key, file_path
            )
            if if_entities is not None:
                maybe_nodes[if_entities["entity_name"]].append(if_entities)
                continue

            if_relation = _handle_single_relationship_extraction(
                record_attributes, chunk_key, file_path
            )
            if if_relation is not None:
                maybe_edges[(if_relation["src_id"], if_relation["tgt_id"])].append(
                    if_relation
                )

        return maybe_nodes, maybe_edges

special_interest = CHEATSHEETS.get("special_interests", "Focus on metadata fields and their relationships")
output_nodes, output_edges = extract_entities(
    text=text, 
    entity_types=PROMPTS["DEFAULT_ENTITY_TYPES"], 
    special_interest=special_interest
)
# Out:
# ----------------
# response.choices[0].message.content:
#  ("entity"<|>"Groot Zeegras"<|>"Metadata date"<|>"Contains data on the coverage percentages of Groot zeegras, Klein zeegras, Snavelruppia, and total biomass of seagrasses per 20x20 meter area."<|>"Metadata date"<|>"N/A")##
# ("entity"<|>"Groot Zeegras"<|>"Metadata language"<|>"Dutch; Flemish"<|>"Metadata language"<|>"N/A")##
# ("entity"<|>"Groot Zeegras"<|>"Responsible organization metadata"<|>"Rijkswaterstaat CIV"<|>"Responsible organization metadata"<|>"N/A")##
# ("entity"<|>"Groot Zeegras"<|>"Landing page"<|>"https://open.rijkswaterstaat.nl/overige-publicaties/2024/metadatabijsluiter-zeegrasdata/"<|>"Landing page"<|>"N/A")##
# ("entity"<|>"Groot Zeegras"<|>"Title"<|>"WMR - TMAP: Ecotopenkaart"<|>"Title"<|>"N/A")##
# ("entity"<|>"Groot Zeegras"<|>"Description"<|>"Dataset for mapping ecotopes in the Wadden Sea region using the RijksWateren-EcotopenStelsel system."<|>"Description"<|>"N/A")##
# ("entity"<|>"Groot Zeegras"<|>"Unique Identifier"<|>"A0h06_NlSEuNlium5OO3FA"<|>"Unique Identifier"<|>"N/A")##
# ("entity"<|>"Groot Zeegras"<|>"Resource type"<|>"Dataset"<|>"Resource type"<|>"N/A")##
# ("entity"<|>"Groot Zeegras"<|>"Keywords"<|>"TMAP, Trilaterale Waddenzee, UNESCO Werelderfgoed, Natuurwaarde, Ecotopen"<|>"Keywords"<|>"N/A")##
# ("entity"<|>"Groot Zeegras"<|>"Data creator"<|>"Wageningen Marine Research"<|>"Data creator"<|>"N/A")##
# ("entity"<|>"Groot Zeegras"<|>"Data contact point"<|>"info@wur.nl"<|>"Data contact point"<|>"N/A")##
# ("entity"<|>"Groot Zeegras"<|>"Data publisher"<|>"Rijkswaterstaat"<|>"Data publisher"<|>"N/A")##
# ("entity"<|>"Groot Zeegras"<|>"Spatial coverage"<|>"Waddenzee vastelandkwelders, Waddeneilanden-Oost, Eems-Dollard, Waddenzee vastelandkwelders, Noord-Holland, Oosterschelde, Waddeneilanden-West, Noord-Groningen, Schiermonnikoog, Eems, Rottumerplaat, Noord-Holland, Terschelling-Oost, Oosterschelde-Oost, Oosterschelde-Midden, Oosterschelde-Noord, Griend, EB7"<|>"Spatial coverage"<|>"N/A")##
# ("entity"<|>"Groot Zeegras"<|>"Spatial resolution"<|>"N/A"<|>"Spatial resolution"<|>"N/A")##
# ("entity"<|>"Groot Zeegras"<|>"Spatial reference system"<|>"N/A"<|>"Spatial reference system"<|>"N/A")##
# ("entity"<|>"Groot Zeegras"<|>"Temporal coverage"<|>"N/A"<|>"Temporal coverage"<|>"N/A")##
# ("entity"<|>"Groot Zeegras"<|>"Temporal resolution"<|>"N/A"<|>"Temporal resolution"<|>"N/A")##
# ("entity"<|>"Groot Zeegras"<|>"License"<|>"N/A"<|>"License"<|>"N/A")##
# ("entity"<|>"Groot Zeegras"<|>"Access rights"<|>"OtherRestrictions"<|>"Access rights"<|>"N/A")##
# ("entity"<|>"Groot Zeegras"<|>"Distribution access URL"<|>"N/A"<|>"Distribution access URL"<|>"N/A")##
# ("entity"<|>"Groot Zeegras"<|>"Distribution format"<|>"gml+xml"<|>"Distribution format"<|>"N/A")##
# ("entity"<|>"Groot Zeegras"<|>"Distribution byte size"<|>"N/A"<|>"Distribution byte size"<|>"N/A")##
# <|COMPLETE|>
# Extracted records: ['("entity"<|>"Groot Zeegras"<|>"Metadata date"<|>"Contains data on the coverage percentages of Groot zeegras, Klein zeegras, Snavelruppia, and total biomass of seagrasses per 20x20 meter area."<|>"Metadata date"<|>"N/A")', '("entity"<|>"Groot Zeegras"<|>"Metadata language"<|>"Dutch; Flemish"<|>"Metadata language"<|>"N/A")', '("entity"<|>"Groot Zeegras"<|>"Responsible organization metadata"<|>"Rijkswaterstaat CIV"<|>"Responsible organization metadata"<|>"N/A")', '("entity"<|>"Groot Zeegras"<|>"Landing page"<|>"https://open.rijkswaterstaat.nl/overige-publicaties/2024/metadatabijsluiter-zeegrasdata/"<|>"Landing page"<|>"N/A")', '("entity"<|>"Groot Zeegras"<|>"Title"<|>"WMR - TMAP: Ecotopenkaart"<|>"Title"<|>"N/A")', '("entity"<|>"Groot Zeegras"<|>"Description"<|>"Dataset for mapping ecotopes in the Wadden Sea region using the RijksWateren-EcotopenStelsel system."<|>"Description"<|>"N/A")', '("entity"<|>"Groot Zeegras"<|>"Unique Identifier"<|>"A0h06_NlSEuNlium5OO3FA"<|>"Unique Identifier"<|>"N/A")', '("entity"<|>"Groot Zeegras"<|>"Resource type"<|>"Dataset"<|>"Resource type"<|>"N/A")', '("entity"<|>"Groot Zeegras"<|>"Keywords"<|>"TMAP, Trilaterale Waddenzee, UNESCO Werelderfgoed, Natuurwaarde, Ecotopen"<|>"Keywords"<|>"N/A")', '("entity"<|>"Groot Zeegras"<|>"Data creator"<|>"Wageningen Marine Research"<|>"Data creator"<|>"N/A")', '("entity"<|>"Groot Zeegras"<|>"Data contact point"<|>"info@wur.nl"<|>"Data contact point"<|>"N/A")', '("entity"<|>"Groot Zeegras"<|>"Data publisher"<|>"Rijkswaterstaat"<|>"Data publisher"<|>"N/A")', '("entity"<|>"Groot Zeegras"<|>"Spatial coverage"<|>"Waddenzee vastelandkwelders, Waddeneilanden-Oost, Eems-Dollard, Waddenzee vastelandkwelders, Noord-Holland, Oosterschelde, Waddeneilanden-West, Noord-Groningen, Schiermonnikoog, Eems, Rottumerplaat, Noord-Holland, Terschelling-Oost, Oosterschelde-Oost, Oosterschelde-Midden, Oosterschelde-Noord, Griend, EB7"<|>"Spatial coverage"<|>"N/A")', '("entity"<|>"Groot Zeegras"<|>"Spatial resolution"<|>"N/A"<|>"Spatial resolution"<|>"N/A")', '("entity"<|>"Groot Zeegras"<|>"Spatial reference system"<|>"N/A"<|>"Spatial reference system"<|>"N/A")', '("entity"<|>"Groot Zeegras"<|>"Temporal coverage"<|>"N/A"<|>"Temporal coverage"<|>"N/A")', '("entity"<|>"Groot Zeegras"<|>"Temporal resolution"<|>"N/A"<|>"Temporal resolution"<|>"N/A")', '("entity"<|>"Groot Zeegras"<|>"License"<|>"N/A"<|>"License"<|>"N/A")', '("entity"<|>"Groot Zeegras"<|>"Access rights"<|>"OtherRestrictions"<|>"Access rights"<|>"N/A")', '("entity"<|>"Groot Zeegras"<|>"Distribution access URL"<|>"N/A"<|>"Distribution access URL"<|>"N/A")', '("entity"<|>"Groot Zeegras"<|>"Distribution format"<|>"gml+xml"<|>"Distribution format"<|>"N/A")', '("entity"<|>"Groot Zeegras"<|>"Distribution byte size"<|>"N/A"<|>"Distribution byte size"<|>"N/A")']
#
# Processing record: ("entity"<|>"Groot Zeegras"<|>"Metadata date"<|>"Contains data on the coverage percentages of Groot zeegras, Klein zeegras, Snavelruppia, and total biomass of seagrasses per 20x20 meter area."<|>"Metadata date"<|>"N/A")
# Processing record: ("entity"<|>"Groot Zeegras"<|>"Metadata language"<|>"Dutch; Flemish"<|>"Metadata language"<|>"N/A")
# Processing record: ("entity"<|>"Groot Zeegras"<|>"Responsible organization metadata"<|>"Rijkswaterstaat CIV"<|>"Responsible organization metadata"<|>"N/A")
# Processing record: ("entity"<|>"Groot Zeegras"<|>"Landing page"<|>"https://open.rijkswaterstaat.nl/overige-publicaties/2024/metadatabijsluiter-zeegrasdata/"<|>"Landing page"<|>"N/A")
# Processing record: ("entity"<|>"Groot Zeegras"<|>"Title"<|>"WMR - TMAP: Ecotopenkaart"<|>"Title"<|>"N/A")
# Processing record: ("entity"<|>"Groot Zeegras"<|>"Description"<|>"Dataset for mapping ecotopes in the Wadden Sea region using the RijksWateren-EcotopenStelsel system."<|>"Description"<|>"N/A")
# Processing record: ("entity"<|>"Groot Zeegras"<|>"Unique Identifier"<|>"A0h06_NlSEuNlium5OO3FA"<|>"Unique Identifier"<|>"N/A")
# Processing record: ("entity"<|>"Groot Zeegras"<|>"Resource type"<|>"Dataset"<|>"Resource type"<|>"N/A")
# Processing record: ("entity"<|>"Groot Zeegras"<|>"Keywords"<|>"TMAP, Trilaterale Waddenzee, UNESCO Werelderfgoed, Natuurwaarde, Ecotopen"<|>"Keywords"<|>"N/A")
# Processing record: ("entity"<|>"Groot Zeegras"<|>"Data creator"<|>"Wageningen Marine Research"<|>"Data creator"<|>"N/A")
# Processing record: ("entity"<|>"Groot Zeegras"<|>"Data contact point"<|>"info@wur.nl"<|>"Data contact point"<|>"N/A")
# Processing record: ("entity"<|>"Groot Zeegras"<|>"Data publisher"<|>"Rijkswaterstaat"<|>"Data publisher"<|>"N/A")
# Processing record: ("entity"<|>"Groot Zeegras"<|>"Spatial coverage"<|>"Waddenzee vastelandkwelders, Waddeneilanden-Oost, Eems-Dollard, Waddenzee vastelandkwelders, Noord-Holland, Oosterschelde, Waddeneilanden-West, Noord-Groningen, Schiermonnikoog, Eems, Rottumerplaat, Noord-Holland, Terschelling-Oost, Oosterschelde-Oost, Oosterschelde-Midden, Oosterschelde-Noord, Griend, EB7"<|>"Spatial coverage"<|>"N/A")
# Processing record: ("entity"<|>"Groot Zeegras"<|>"Spatial resolution"<|>"N/A"<|>"Spatial resolution"<|>"N/A")
# Processing record: ("entity"<|>"Groot Zeegras"<|>"Spatial reference system"<|>"N/A"<|>"Spatial reference system"<|>"N/A")
# Processing record: ("entity"<|>"Groot Zeegras"<|>"Temporal coverage"<|>"N/A"<|>"Temporal coverage"<|>"N/A")
# Processing record: ("entity"<|>"Groot Zeegras"<|>"Temporal resolution"<|>"N/A"<|>"Temporal resolution"<|>"N/A")
# Processing record: ("entity"<|>"Groot Zeegras"<|>"License"<|>"N/A"<|>"License"<|>"N/A")
# Processing record: ("entity"<|>"Groot Zeegras"<|>"Access rights"<|>"OtherRestrictions"<|>"Access rights"<|>"N/A")
# Processing record: ("entity"<|>"Groot Zeegras"<|>"Distribution access URL"<|>"N/A"<|>"Distribution access URL"<|>"N/A")
# Processing record: ("entity"<|>"Groot Zeegras"<|>"Distribution format"<|>"gml+xml"<|>"Distribution format"<|>"N/A")
# Processing record: ("entity"<|>"Groot Zeegras"<|>"Distribution byte size"<|>"N/A"<|>"Distribution byte size"<|>"N/A")
# Entity extraction error: empty entity name in: ['"entity"', '""', '"Resource type"', '"Represents the type of resource, not provided in the text"', '"Real Data"', '"<Nightly Inference>"']
# Entity extraction error: empty entity name in: ['"entity"', '""', '"Data creator"', '"Represents the entity responsible for creating the data, not provided in the text"', '"Real Data"', '"<Nightly Inference>"']
# Entity extraction error: empty entity name in: ['"entity"', '""', '"Data contact point"', '"Represents the contact point for the data, not provided in the text"', '"Real Data"', '"<Nightly Inference>"']
# Entity extraction error: empty entity name in: ['"entity"', '""', '"Data publisher"', '"Represents the entity responsible for publishing the data, not provided in the text"', '"Real Data"', '"<Nightly Inference>"']
# Entity extraction error: empty entity name in: ['"entity"', '""', '"Spatial coverage"', '"Describes the spatial extent of the data, not provided in the text"', '"Real Data"', '"<Nightly Inference>"']
# Entity extraction error: empty entity name in: ['"entity"', '""', '"Spatial reference system"', '"Specifies the spatial reference system used, not provided in the text"', '"Real Data"', '"<Nightly Inference>"']
# Entity extraction error: empty entity name in: ['"entity"', '""', '"Temporal coverage"', '"Indicates the temporal extent of the data, not provided in the text"', '"Real Data"', '"<Nightly Inference>"']
# Entity extraction error: empty entity name in: ['"entity"', '""', '"Temporal resolution"', '"Specifies the temporal resolution of the data, not provided in the text"', '"Real Data"', '"<Nightly Inference>"']
# Entity extraction error: empty entity name in: ['"entity"', '""', '"License"', '"Describes the license under which the data is distributed, not provided in the text"', '"Real Data"', '"<Nightly Inference>"']
# Entity extraction error: empty entity name in: ['"entity"', '""', '"Distribution byte size"', '"Specifies the byte size of the distributed data, not provided in the text"', '"Real Data"', '"<Nightly Inference>"']
# ----------------
# response.choices[0].message.content:
#  ("entity"<|>"Copyright"<|>"Access rights"<|>"Specifies the access constraints based on copyright regulations"<|>"Real Data"<|>"<Nightly Inference>")##
# ("entity"<|>"Geen gebruiks limitaties"<|>"Access rights"<|>"Indicates the absence of specific use limitations"<|>"Real Data"<|>"<Nightly Inference>")##
# ("entity"<|>"None"<|>"Spatial resolution"<|>"Represents the absence of a specific spatial resolution value"<|>"Real Data"<|>"<Nightly Inference>")##
# ("entity"<|>"Dutch"<|>"Metadata language"<|>"Denotes the language of the metadata as Dutch"<|>"Real Data"<|>"<Nightly Inference>")##
# ("entity"<|>"Biotisch"<|>"Keywords"<|>"Relates to the biotic topic category"<|>"Real Data"<|>"<Nightly Inference>")##
# ("entity"<|>"Waterbodem"<|>"Keywords"<|>"Relates to the water bottom topic category"<|>"Real Data"<|>"<Nightly Inference>")##
# ("entity"<|>""<|>"Resource type"<|>"Represents the type of resource, not provided in the text"<|>"Real Data"<|>"<Nightly Inference>")##
# ("entity"<|>""<|>"Data creator"<|>"Represents the entity responsible for creating the data, not provided in the text"<|>"Real Data"<|>"<Nightly Inference>")##
# ("entity"<|>""<|>"Data contact point"<|>"Represents the contact point for the data, not provided in the text"<|>"Real Data"<|>"<Nightly Inference>")##
# ("entity"<|>""<|>"Data publisher"<|>"Represents the entity responsible for publishing the data, not provided in the text"<|>"Real Data"<|>"<Nightly Inference>")##
# ("entity"<|>""<|>"Spatial coverage"<|>"Describes the spatial extent of the data, not provided in the text"<|>"Real Data"<|>"<Nightly Inference>")##
# ("entity"<|>""<|>"Spatial reference system"<|>"Specifies the spatial reference system used, not provided in the text"<|>"Real Data"<|>"<Nightly Inference>")##
# ("entity"<|>""<|>"Temporal coverage"<|>"Indicates the temporal extent of the data, not provided in the text"<|>"Real Data"<|>"<Nightly Inference>")##
# ("entity"<|>""<|>"Temporal resolution"<|>"Specifies the temporal resolution of the data, not provided in the text"<|>"Real Data"<|>"<Nightly Inference>")##
# ("entity"<|>""<|>"License"<|>"Describes the license under which the data is distributed, not provided in the text"<|>"Real Data"<|>"<Nightly Inference>")##
# ("entity"<|>"https://viewer.openearth.nl/wadden-viewer/?layers=93966870&amp;layerNames=WMR+-+TMAP%3A+Ecotopenkaart&amp;folders=143810679%2C93790346"<|>"Distribution access URL"<|>"Provides a URL for accessing the data through the Wadden viewer"<|>"Real Data"<|>"<Nightly Inference>")##
# ("entity"<|>"gml+xml 3.2.1"<|>"Distribution format"<|>"Specifies the distribution format of the data as GML version 3.2.1"<|>"Real Data"<|>"<Nightly Inference>")##
# ("entity"<|>""<|>"Distribution byte size"<|>"Specifies the byte size of the distributed data, not provided in the text"<|>"Real Data"<|>"<Nightly Inference>")##
# ("entity"<|>"Wadden viewer"<|>"Title"<|>"Refers to the Wadden viewer application"<|>"Real Data"<|>"<Nightly Inference>")##
# ("entity"<|>"Bekijk deze data in de Wadden viewer"<|>"Description"<|>"Encourages viewing the data in the Wadden viewer"<|>"Real Data"<|>"<Nightly Inference")##
# ("entity"<|>"Wageningen Marine Research"<|>"Title"<|>"Refers to the organization Wageningen Marine Research"<|>"Real Data"<|>"<Nightly Inference>")##
# ("entity"<|>"Website met algemene informatie over TMAP"<|>"Description"<|>"Describes the content of the Wageningen Marine Research website"<|>"Real Data"<|>"<Nightly Inference")##
# ("entity"<|>"Referentie"<|>"Title"<|>"Refers to a reference document"<|>"Real Data"<|>"<Nightly Inference>")##
# ("entity"<|>"Baptist, M.J., et al, 2016. Ecotopenkaart Waddenzee volgens de ZES.1 Typologie. Wageningen Marine Research rapport C103/16."<|>"Description"<|>"Describes the content of the reference document"<|>"Real Data"<|>"<Nightly Inference")##
# ("entity"<|>"Download"<|>"Title"<|>"Refers to the download option"<|>"Real Data"<|>"<Nightly Inference>")##
# ("entity"<|>"Download de data via de Wadden viewer"<|>"Description"<|>"Encourages downloading the data via the Wadden viewer"<|>"Real Data"<|>"<Nightly Inference")##
# ("entity"<|>"WS3shp:WS3_Ecotope_Map"<|>"Title"<|>"Refers to a specific map layer"<|>"Real Data"<|>"<Nightly Inference>")##
# ("entity"<|>"WMS"<|>"Description"<|>"Indicates the type of service provided by the map layer"<|>"Real Data"<|>"<Nightly Inference")##
# <|COMPLETE|>
# Extracted records: ['("entity"<|>"Copyright"<|>"Access rights"<|>"Specifies the access constraints based on copyright regulations"<|>"Real Data"<|>"<Nightly Inference>")', '("entity"<|>"Geen gebruiks limitaties"<|>"Access rights"<|>"Indicates the absence of specific use limitations"<|>"Real Data"<|>"<Nightly Inference>")', '("entity"<|>"None"<|>"Spatial resolution"<|>"Represents the absence of a specific spatial resolution value"<|>"Real Data"<|>"<Nightly Inference>")', '("entity"<|>"Dutch"<|>"Metadata language"<|>"Denotes the language of the metadata as Dutch"<|>"Real Data"<|>"<Nightly Inference>")', '("entity"<|>"Biotisch"<|>"Keywords"<|>"Relates to the biotic topic category"<|>"Real Data"<|>"<Nightly Inference>")', '("entity"<|>"Waterbodem"<|>"Keywords"<|>"Relates to the water bottom topic category"<|>"Real Data"<|>"<Nightly Inference>")', '("entity"<|>""<|>"Resource type"<|>"Represents the type of resource, not provided in the text"<|>"Real Data"<|>"<Nightly Inference>")', '("entity"<|>""<|>"Data creator"<|>"Represents the entity responsible for creating the data, not provided in the text"<|>"Real Data"<|>"<Nightly Inference>")', '("entity"<|>""<|>"Data contact point"<|>"Represents the contact point for the data, not provided in the text"<|>"Real Data"<|>"<Nightly Inference>")', '("entity"<|>""<|>"Data publisher"<|>"Represents the entity responsible for publishing the data, not provided in the text"<|>"Real Data"<|>"<Nightly Inference>")', '("entity"<|>""<|>"Spatial coverage"<|>"Describes the spatial extent of the data, not provided in the text"<|>"Real Data"<|>"<Nightly Inference>")', '("entity"<|>""<|>"Spatial reference system"<|>"Specifies the spatial reference system used, not provided in the text"<|>"Real Data"<|>"<Nightly Inference>")', '("entity"<|>""<|>"Temporal coverage"<|>"Indicates the temporal extent of the data, not provided in the text"<|>"Real Data"<|>"<Nightly Inference>")', '("entity"<|>""<|>"Temporal resolution"<|>"Specifies the temporal resolution of the data, not provided in the text"<|>"Real Data"<|>"<Nightly Inference>")', '("entity"<|>""<|>"License"<|>"Describes the license under which the data is distributed, not provided in the text"<|>"Real Data"<|>"<Nightly Inference>")', '("entity"<|>"https://viewer.openearth.nl/wadden-viewer/?layers=93966870&amp;layerNames=WMR+-+TMAP%3A+Ecotopenkaart&amp;folders=143810679%2C93790346"<|>"Distribution access URL"<|>"Provides a URL for accessing the data through the Wadden viewer"<|>"Real Data"<|>"<Nightly Inference>")', '("entity"<|>"gml+xml 3.2.1"<|>"Distribution format"<|>"Specifies the distribution format of the data as GML version 3.2.1"<|>"Real Data"<|>"<Nightly Inference>")', '("entity"<|>""<|>"Distribution byte size"<|>"Specifies the byte size of the distributed data, not provided in the text"<|>"Real Data"<|>"<Nightly Inference>")', '("entity"<|>"Wadden viewer"<|>"Title"<|>"Refers to the Wadden viewer application"<|>"Real Data"<|>"<Nightly Inference>")', '("entity"<|>"Bekijk deze data in de Wadden viewer"<|>"Description"<|>"Encourages viewing the data in the Wadden viewer"<|>"Real Data"<|>"<Nightly Inference")', '("entity"<|>"Wageningen Marine Research"<|>"Title"<|>"Refers to the organization Wageningen Marine Research"<|>"Real Data"<|>"<Nightly Inference>")', '("entity"<|>"Website met algemene informatie over TMAP"<|>"Description"<|>"Describes the content of the Wageningen Marine Research website"<|>"Real Data"<|>"<Nightly Inference")', '("entity"<|>"Referentie"<|>"Title"<|>"Refers to a reference document"<|>"Real Data"<|>"<Nightly Inference>")', '("entity"<|>"Baptist, M.J., et al, 2016. Ecotopenkaart Waddenzee volgens de ZES.1 Typologie. Wageningen Marine Research rapport C103/16."<|>"Description"<|>"Describes the content of the reference document"<|>"Real Data"<|>"<Nightly Inference")', '("entity"<|>"Download"<|>"Title"<|>"Refers to the download option"<|>"Real Data"<|>"<Nightly Inference>")', '("entity"<|>"Download de data via de Wadden viewer"<|>"Des ...
#
# Processing record: ("entity"<|>"Copyright"<|>"Access rights"<|>"Specifies the access constraints based on copyright regulations"<|>"Real Data"<|>"<Nightly Inference>")
# Processing record: ("entity"<|>"Geen gebruiks limitaties"<|>"Access rights"<|>"Indicates the absence of specific use limitations"<|>"Real Data"<|>"<Nightly Inference>")
# Processing record: ("entity"<|>"None"<|>"Spatial resolution"<|>"Represents the absence of a specific spatial resolution value"<|>"Real Data"<|>"<Nightly Inference>")
# Processing record: ("entity"<|>"Dutch"<|>"Metadata language"<|>"Denotes the language of the metadata as Dutch"<|>"Real Data"<|>"<Nightly Inference>")
# Processing record: ("entity"<|>"Biotisch"<|>"Keywords"<|>"Relates to the biotic topic category"<|>"Real Data"<|>"<Nightly Inference>")
# Processing record: ("entity"<|>"Waterbodem"<|>"Keywords"<|>"Relates to the water bottom topic category"<|>"Real Data"<|>"<Nightly Inference>")
# Processing record: ("entity"<|>""<|>"Resource type"<|>"Represents the type of resource, not provided in the text"<|>"Real Data"<|>"<Nightly Inference>")
# Processing record: ("entity"<|>""<|>"Data creator"<|>"Represents the entity responsible for creating the data, not provided in the text"<|>"Real Data"<|>"<Nightly Inference>")
# Processing record: ("entity"<|>""<|>"Data contact point"<|>"Represents the contact point for the data, not provided in the text"<|>"Real Data"<|>"<Nightly Inference>")
# Processing record: ("entity"<|>""<|>"Data publisher"<|>"Represents the entity responsible for publishing the data, not provided in the text"<|>"Real Data"<|>"<Nightly Inference>")
# Processing record: ("entity"<|>""<|>"Spatial coverage"<|>"Describes the spatial extent of the data, not provided in the text"<|>"Real Data"<|>"<Nightly Inference>")
# Processing record: ("entity"<|>""<|>"Spatial reference system"<|>"Specifies the spatial reference system used, not provided in the text"<|>"Real Data"<|>"<Nightly Inference>")
# Processing record: ("entity"<|>""<|>"Temporal coverage"<|>"Indicates the temporal extent of the data, not provided in the text"<|>"Real Data"<|>"<Nightly Inference>")
# Processing record: ("entity"<|>""<|>"Temporal resolution"<|>"Specifies the temporal resolution of the data, not provided in the text"<|>"Real Data"<|>"<Nightly Inference>")
# Processing record: ("entity"<|>""<|>"License"<|>"Describes the license under which the data is distributed, not provided in the text"<|>"Real Data"<|>"<Nightly Inference>")
# Processing record: ("entity"<|>"https://viewer.openearth.nl/wadden-viewer/?layers=93966870&amp;layerNames=WMR+-+TMAP%3A+Ecotopenkaart&amp;folders=143810679%2C93790346"<|>"Distribution access URL"<|>"Provides a URL for accessing the data through the Wadden viewer"<|>"Real Data"<|>"<Nightly Inference>")
# Processing record: ("entity"<|>"gml+xml 3.2.1"<|>"Distribution format"<|>"Specifies the distribution format of the data as GML version 3.2.1"<|>"Real Data"<|>"<Nightly Inference>")
# Processing record: ("entity"<|>""<|>"Distribution byte size"<|>"Specifies the byte size of the distributed data, not provided in the text"<|>"Real Data"<|>"<Nightly Inference>")
# Processing record: ("entity"<|>"Wadden viewer"<|>"Title"<|>"Refers to the Wadden viewer application"<|>"Real Data"<|>"<Nightly Inference>")
# Processing record: ("entity"<|>"Bekijk deze data in de Wadden viewer"<|>"Description"<|>"Encourages viewing the data in the Wadden viewer"<|>"Real Data"<|>"<Nightly Inference")
# Processing record: ("entity"<|>"Wageningen Marine Research"<|>"Title"<|>"Refers to the organization Wageningen Marine Research"<|>"Real Data"<|>"<Nightly Inference>")
# Processing record: ("entity"<|>"Website met algemene informatie over TMAP"<|>"Description"<|>"Describes the content of the Wageningen Marine Research website"<|>"Real Data"<|>"<Nightly Inference")
# Processing record: ("entity"<|>"Referentie"<|>"Title"<|>"Refers to a reference document"<|>"Real Data"<|>"<Nightly Inference>")
# Processing record: ("entity"<|>"Baptist, M.J., et al, 2016. Ecotopenkaart Waddenzee volgens de ZES.1 Typologie. Wageningen Marine Research rapport C103/16."<|>"Description"<|>"Describes the content of the reference document"<|>"Real Data"<|>"<Nightly Inference")
# Processing record: ("entity"<|>"Download"<|>"Title"<|>"Refers to the download option"<|>"Real Data"<|>"<Nightly Inference>")
# Processing record: ("entity"<|>"Download de data via de Wadden viewer"<|>"Description"<|>"Encourages downloading the data via the Wadden viewer"<|>"Real Data"<|>"<Nightly Inference")
# Processing record: ("entity"<|>"WS3shp:WS3_Ecotope_Map"<|>"Title"<|>"Refers to a specific map layer"<|>"Real Data"<|>"<Nightly Inference>")
# Processing record: ("entity"<|>"WMS"<|>"Description"<|>"Indicates the type of service provided by the map layer"<|>"Real Data"<|>"<Nightly Inference")

# %%
# Create a dictionary to store entity_type: [(entity_name, description), ...]
entity_type_map = {}

for entity_group in output_nodes.values():
    for item in entity_group:
        entity_type = item.get('entity_type')
        entity_name = item.get('entity_name')
        description = item.get('description')

        # Initialize the list for this entity_type if not already present
        if entity_type not in entity_type_map:
            entity_type_map[entity_type] = []

        # Append the (entity_name, description) pair
        entity_type_map[entity_type].append((entity_name, description))

# Example: print results
for entity_type, pairs in entity_type_map.items():
    print(f"{entity_type}:")
    for name, desc in pairs:
        print(f"  - ({name}, {desc})")
# Out:
# Metadata date:
#   - (Groot Zeegras, Contains data on the coverage percentages of Groot zeegras, Klein zeegras, Snavelruppia, and total biomass of seagrasses per 20x20 meter area.)
# Metadata language:
#   - (Groot Zeegras, Dutch; Flemish)
#   - (Dutch, Denotes the language of the metadata as Dutch)
# Responsible organization metadata:
#   - (Groot Zeegras, Rijkswaterstaat CIV)
# Landing page:
#   - (Groot Zeegras, https://open.rijkswaterstaat.nl/overige-publicaties/2024/metadatabijsluiter-zeegrasdata/)
# Title:
#   - (Groot Zeegras, WMR - TMAP: Ecotopenkaart)
#   - (Wadden viewer, Refers to the Wadden viewer application)
#   - (Wageningen Marine Research, Refers to the organization Wageningen Marine Research)
#   - (Referentie, Refers to a reference document)
#   - (Download, Refers to the download option)
#   - (WS3shp:WS3_Ecotope_Map, Refers to a specific map layer)
# Description:
#   - (Groot Zeegras, Dataset for mapping ecotopes in the Wadden Sea region using the RijksWateren-EcotopenStelsel system.)
#   - (Bekijk deze data in de Wadden viewer, Encourages viewing the data in the Wadden viewer)
#   - (Website met algemene informatie over TMAP, Describes the content of the Wageningen Marine Research website)
#   - (Baptist, M.J., et al, 2016. Ecotopenkaart Waddenzee volgens de ZES.1 Typologie. Wageningen Marine Research rapport C103/16., Describes the content of the reference document)
#   - (Download de data via de Wadden viewer, Encourages downloading the data via the Wadden viewer)
#   - (WMS, Indicates the type of service provided by the map layer)
# Unique Identifier:
#   - (Groot Zeegras, A0h06_NlSEuNlium5OO3FA)
# Resource type:
#   - (Groot Zeegras, Dataset)
# Keywords:
#   - (Groot Zeegras, TMAP, Trilaterale Waddenzee, UNESCO Werelderfgoed, Natuurwaarde, Ecotopen)
#   - (Biotisch, Relates to the biotic topic category)
#   - (Waterbodem, Relates to the water bottom topic category)
# Data creator:
#   - (Groot Zeegras, Wageningen Marine Research)
# Data contact point:
#   - (Groot Zeegras, info@wur.nl)
# Data publisher:
#   - (Groot Zeegras, Rijkswaterstaat)
# Spatial coverage:
#   - (Groot Zeegras, Waddenzee vastelandkwelders, Waddeneilanden-Oost, Eems-Dollard, Waddenzee vastelandkwelders, Noord-Holland, Oosterschelde, Waddeneilanden-West, Noord-Groningen, Schiermonnikoog, Eems, Rottumerplaat, Noord-Holland, Terschelling-Oost, Oosterschelde-Oost, Oosterschelde-Midden, Oosterschelde-Noord, Griend, EB7)
# Spatial resolution:
#   - (Groot Zeegras, N/A)
#   - (None, Represents the absence of a specific spatial resolution value)
# Spatial reference system:
#   - (Groot Zeegras, N/A)
# Temporal coverage:
#   - (Groot Zeegras, N/A)
# Temporal resolution:
#   - (Groot Zeegras, N/A)
# License:
#   - (Groot Zeegras, N/A)
# Access rights:
#   - (Groot Zeegras, OtherRestrictions)
#   - (Copyright, Specifies the access constraints based on copyright regulations)
#   - (Geen gebruiks limitaties, Indicates the absence of specific use limitations)
# Distribution access URL:
#   - (Groot Zeegras, N/A)
#   - (https://viewer.openearth.nl/wadden-viewer/?layers=93966870&layerNames=WMR+-+TMAP%3A+Ecotopenkaart&folders=143810679%2C93790346, Provides a URL for accessing the data through the Wadden viewer)
# Distribution format:
#   - (Groot Zeegras, gml+xml)
#   - (gml+xml 3.2.1, Specifies the distribution format of the data as GML version 3.2.1)
# Distribution byte size:
#   - (Groot Zeegras, N/A)

# %%
CHEATSHEETS["special_interests"]
# Out:
# '\n- Metadata date: This element contains the date on which the metadata was created or updated. The\n    date format is YYYY-MM-DD (with hyphens).\n- Metadata language: This element records the language in which the metadata is written. It contains\n    the code of the language used in the metadata text. Only the three-letter codes from ISO 639-2/B\n    (bibliographic codes) should be used, as defined in ISO 639-2. The code for Dutch is "dut".\n- Responsible organization metadata: This element contains the name of the organization responsible\n    for the metadata. Use the full written name of the responsible organization. An abbreviation may\n    be added to the organization name. For correct official government organization names, refer to\n    the list of government organizations. Preferably, fill in this element as a gmx:Anchor, where the\n    href attribute points to a URI that describes the organization.\n    Example: source:\n        <Anchor \n        xlink:href="https://www.tno.nl/nl/over-tno/organisatie">\n            Nederlandse organisatie voor \n            toegepast-natuurwetenschappelijk onderzoek (TNO)\n        </Anchor>\n        result: Nederlandse organisatie voor toegepast-natuurwetenschappelijk onderzoek (TNO).\n'
